# %% [markdown]
# # DataFrame 인덱싱

# %%
import pandas as pd

# %%
iphone_df = pd.read_csv('data/iphone.csv', index_col=0)
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df.loc['iPhone 8', '메모리']  # iphone_df.loc['row 명', 'column 명']
# Out:
# '2GB'

# %%
iphone_df.loc['iPhone X', :]   # 전체 컬럼
# Out:
# 출시일        2017-11-03
# 디스플레이             5.8
# 메모리               3GB
# 출시 버전        iOS 11.1
# Face ID           Yes
# Name: iPhone X, dtype: object

# %%
iphone_df.loc['iPhone X']
# Out:
# 출시일        2017-11-03
# 디스플레이             5.8
# 메모리               3GB
# 출시 버전        iOS 11.1
# Face ID           Yes
# Name: iPhone X, dtype: object

# %%
type(iphone_df.loc['iPhone X'])  # Series는 pandas의 일차원 자료형
# Out:
# pandas.core.series.Series

# %%
iphone_df.loc[:, '출시일']
# Out:
# iPhone 7         2016-09-16
# iPhone 7 Plus    2016-09-16
# iPhone 8         2017-09-22
# iPhone 8 Plus    2017-09-22
# iPhone X         2017-11-03
# iPhone XS        2018-09-21
# iPhone XS Max    2018-09-21
# Name: 출시일, dtype: object

# %%
iphone_df['출시일']  # loc 없음
# Out:
# iPhone 7         2016-09-16
# iPhone 7 Plus    2016-09-16
# iPhone 8         2017-09-22
# iPhone 8 Plus    2017-09-22
# iPhone X         2017-11-03
# iPhone XS        2018-09-21
# iPhone XS Max    2018-09-21
# Name: 출시일, dtype: object

# %%
type(iphone_df['출시일'])
# Out:
# pandas.core.series.Series

# %%
type(iphone_df.loc['iPhone 8', '메모리'])
# Out:
# str

# %%
# 여러 줄 찾기
import pandas as pd

df = pd.read_csv('data/broadcast.csv', index_col=0)
print(df[['SBS', 'JTBC']])
# Out:
#          SBS   JTBC
# 2011  11.173  7.380
# 2012  11.408  7.878
# 2013   9.673  7.810
# 2014   9.108  7.490
# 2015   9.099  7.267
# 2016   8.669  7.727
# 2017   8.661  9.453

# %%
iphone_df.loc[['iPhone X', 'iPhone 8']]
# Out:
#                  출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone X  2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone 8  2017-09-22    4.7  2GB  iOS 11.0      No

# %%
type(iphone_df.loc[['iPhone X', 'iPhone 8']])
# Out:
# pandas.core.frame.DataFrame

# %%
iphone_df[['Face ID', '출시일', '메모리']]
# Out:
#               Face ID         출시일  메모리
# iPhone 7           No  2016-09-16  2GB
# iPhone 7 Plus      No  2016-09-16  3GB
# iPhone 8           No  2017-09-22  2GB
# iPhone 8 Plus      No  2017-09-22  3GB
# iPhone X          Yes  2017-11-03  3GB
# iPhone XS         Yes  2018-09-21  4GB
# iPhone XS Max     Yes  2018-09-21  4GB

# %%
iphone_df.loc['iPhone 8' : 'iPhone XS']  # Row 여러 줄 가져오기
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes

# %%
iphone_df.loc[: 'iPhone XS']  # iPhone XS까지 row 가져오기
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes

# %%
iphone_df['메모리' : 'Face ID']  # column 슬라이싱으로 여러 줄 가져오는 건 다른 방법으로 사용해야 함.
# Out:
# Empty DataFrame
# Columns: [출시일, 디스플레이, 메모리, 출시 버전, Face ID]
# Index: []

# %%
iphone_df.loc[:, '메모리' : 'Face ID']  # 슬라이싱으로 column 여러 줄 가져오기
# Out:
#                메모리     출시 버전 Face ID
# iPhone 7       2GB  iOS 10.0      No
# iPhone 7 Plus  3GB  iOS 10.0      No
# iPhone 8       2GB  iOS 11.0      No
# iPhone 8 Plus  3GB  iOS 11.0      No
# iPhone X       3GB  iOS 11.1     Yes
# iPhone XS      4GB  iOS 12.0     Yes
# iPhone XS Max  4GB  iOS 12.0     Yes

# %%
iphone_df.loc['iPhone 7':'iPhone X', '메모리':'Face ID']  # column, row 원하는 곳까지 출력
# Out:
#                메모리     출시 버전 Face ID
# iPhone 7       2GB  iOS 10.0      No
# iPhone 7 Plus  3GB  iOS 10.0      No
# iPhone 8       2GB  iOS 11.0      No
# iPhone 8 Plus  3GB  iOS 11.0      No
# iPhone X       3GB  iOS 11.1     Yes

# %% [markdown]
# # DataFrame 조건으로 인덱싱

# %%
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df.loc[[True, False, True, True, False, True, False]]  # index 0,2,3,5번에 해당하는 row 가져오기
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes

# %%
iphone_df.loc[:, [True, False, False, True, False]]
# Out:
#                       출시일     출시 버전
# iPhone 7       2016-09-16  iOS 10.0
# iPhone 7 Plus  2016-09-16  iOS 10.0
# iPhone 8       2017-09-22  iOS 11.0
# iPhone 8 Plus  2017-09-22  iOS 11.0
# iPhone X       2017-11-03  iOS 11.1
# iPhone XS      2018-09-21  iOS 12.0
# iPhone XS Max  2018-09-21  iOS 12.0

# %%
iphone_df['디스플레이'] > 5  # pandas.core.series.Series
# Out:
# iPhone 7         False
# iPhone 7 Plus     True
# iPhone 8         False
# iPhone 8 Plus     True
# iPhone X          True
# iPhone XS         True
# iPhone XS Max     True
# Name: 디스플레이, dtype: bool

# %%
iphone_df.loc[iphone_df['디스플레이'] > 5]
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df['Face ID'] == 'Yes'
# Out:
# iPhone 7         False
# iPhone 7 Plus    False
# iPhone 8         False
# iPhone 8 Plus    False
# iPhone X          True
# iPhone XS         True
# iPhone XS Max     True
# Name: Face ID, dtype: bool

# %%
iphone_df.loc[iphone_df['Face ID'] == 'Yes']
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
(iphone_df['디스플레이'] > 5) & (iphone_df['Face ID'] == 'Yes')
# Out:
# iPhone 7         False
# iPhone 7 Plus    False
# iPhone 8         False
# iPhone 8 Plus    False
# iPhone X          True
# iPhone XS         True
# iPhone XS Max     True
# dtype: bool

# %%
condition = (iphone_df['디스플레이'] > 5) & (iphone_df['Face ID'] == 'Yes')

# %%
iphone_df[condition]
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
condition = (iphone_df['디스플레이'] > 5) | (iphone_df['Face ID'] == 'Yes')

# %%
iphone_df[condition]
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %% [markdown]
# ### 'KBS'에서 시청률이 30이 넘은 데이터만 확인하기

# %%
import pandas as pd

df = pd.read_csv('data/broadcast.csv', index_col=0)
df.loc[df['KBS'] > 30, 'KBS']
# Out:
# 2011    35.951
# 2012    36.163
# 2013    31.989
# 2014    31.210
# Name: KBS, dtype: float64

# %% [markdown]
# ### 주어진 데이터에서 SBS가 TV CHOSUN보다 더 시청률이 낮았던 시기의 데이터 확인하기

# %%
import pandas as pd

df = pd.read_csv('data/broadcast.csv', index_col=0)
df.loc[df['SBS'] < df['TV CHOSUN'], ['SBS', 'TV CHOSUN']]
# Out:
#         SBS  TV CHOSUN
# 2014  9.108      9.440
# 2015  9.099      9.940
# 2016  8.669      9.829
# 2017  8.661      8.886

# %% [markdown]
# # DataFrame 위치로 인덱싱하기

# %%
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df.iloc[2, 4]  # 2번 row, 4번 cloumn 위치에 해당하는 값.
# Out:
# 'No'

# %%
iphone_df.iloc[[1,3], [1,4]]  # 1,3번 row(7 Plus,8 Plus), 1,4번 column(디스플레이, Face ID)
# Out:
#                디스플레이 Face ID
# iPhone 7 Plus    5.5      No
# iPhone 8 Plus    5.5      No

# %%
iphone_df.iloc[3:, 1:4]  # 3부터 끝까지 row, 1부터 3까지 column
# Out:
#                디스플레이  메모리     출시 버전
# iPhone 8 Plus    5.5  3GB  iOS 11.0
# iPhone X         5.8  3GB  iOS 11.1
# iPhone XS        5.8  4GB  iOS 12.0
# iPhone XS Max    6.5  4GB  iOS 12.0

# %% [markdown]
# ### DataFrame 인덱싱을 하는 방법과 종류 요약
#
# |이름으로 인덱싱하기|기본 형태|단축 형태|
# | :---: | :----: | :-----: |
# |하나의 row 이름|df.loc["row4"]||
# |row 이름의 리스트|df.loc[["row4", "row5", "row3"]]||
# |row 이름의 리스트 슬라이싱|df.loc["row2":"row5"]|df["row2":"row5"]|
# |하나의 column 이름|df.loc[:, "col1"]|df["col1"]|
# |column 이름의 리스트|df.loc[:, ["col4", "col6", "col3"]]|df[["col4", "col6", "col3"]]|
# |column 이름의 리스트 슬라이싱|df.loc[:, "col2":"col5"]| |
#
# <br>
#
# |위치로 인덱싱하기|기본 형태|단축 형태|
# | :---: | :----: | :-----: |
# |하나의 row 위치|df.iloc[8]||
# |row 위치의 리스트|df.iloc[[4, 5, 3]]|
# |row 위치의 리스트 슬라이싱|df.iloc[2:5]|df[2:5]|
# |하나의 column 위치|df.iloc[:, 3]||
# |column 위치의 리스트|df.iloc[:, [3, 5, 6]]||
# |column 위치의 리스트 슬라이싱|df.iloc[:, 3:7]||

# %% [markdown]
# # 데이터 변형하기(추가/삭제)

# %%
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df.loc['iPhone 8', '메모리']
# Out:
# '2GB'

# %%
iphone_df.loc['iPhone 8', '메모리'] = '2.5GB'  # 값 변경

# %%
iphone_df
# Out:
#                       출시일  디스플레이    메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7    2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5    3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2.5GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5    3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8    3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8    4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5    4GB  iOS 12.0     Yes

# %%
iphone_df.loc['iPhone 8']
# Out:
# 출시일        2017-09-22
# 디스플레이             4.7
# 메모리             2.5GB
# 출시 버전        iOS 11.0
# Face ID            No
# Name: iPhone 8, dtype: object

# %%
iphone_df.loc['iPhone 8'] = ['2016-09-22', '4.7', '2GB', 'iOS 11.0', 'No']  # row 한 줄 바꾸기
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16   5.5  3GB  iOS 10.0      No
# iPhone 8       2016-09-22   4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22   5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03   5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21   5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21   6.5  4GB  iOS 12.0     Yes

# %%
iphone_df['디스플레이']
# Out:
# iPhone 7         4.7
# iPhone 7 Plus    5.5
# iPhone 8         4.7
# iPhone 8 Plus    5.5
# iPhone X         5.8
# iPhone XS        5.8
# iPhone XS Max    6.5
# Name: 디스플레이, dtype: object

# %%
iphone_df['디스플레이'] = ['4.7 in', '5.5 in', '4.7 in', '5.5 in', '5.8 in', '5.8 in', '6.5 in']  # column 한 줄 바꾸기
iphone_df
# Out:
#                       출시일   디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16  4.7 in  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16  5.5 in  3GB  iOS 10.0      No
# iPhone 8       2016-09-22  4.7 in  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22  5.5 in  3GB  iOS 11.0      No
# iPhone X       2017-11-03  5.8 in  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21  5.8 in  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21  6.5 in  4GB  iOS 12.0     Yes

# %%
iphone_df['Face ID'] = 'Yes'  # 동일 값으로 한 번에 바꾸기
iphone_df
# Out:
#                       출시일   디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16  4.7 in  2GB  iOS 10.0     Yes
# iPhone 7 Plus  2016-09-16  5.5 in  3GB  iOS 10.0     Yes
# iPhone 8       2016-09-22  4.7 in  2GB  iOS 11.0     Yes
# iPhone 8 Plus  2017-09-22  5.5 in  3GB  iOS 11.0     Yes
# iPhone X       2017-11-03  5.8 in  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21  5.8 in  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21  6.5 in  4GB  iOS 12.0     Yes

# %%
iphone_df[['디스플레이', 'Face ID']]
# Out:
#                 디스플레이 Face ID
# iPhone 7       4.7 in     Yes
# iPhone 7 Plus  5.5 in     Yes
# iPhone 8       4.7 in     Yes
# iPhone 8 Plus  5.5 in     Yes
# iPhone X       5.8 in     Yes
# iPhone XS      5.8 in     Yes
# iPhone XS Max  6.5 in     Yes

# %%
iphone_df[['디스플레이', 'Face ID']] = 'x'
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16     x  2GB  iOS 10.0       x
# iPhone 7 Plus  2016-09-16     x  3GB  iOS 10.0       x
# iPhone 8       2016-09-22     x  2GB  iOS 11.0       x
# iPhone 8 Plus  2017-09-22     x  3GB  iOS 11.0       x
# iPhone X       2017-11-03     x  3GB  iOS 11.1       x
# iPhone XS      2018-09-21     x  4GB  iOS 12.0       x
# iPhone XS Max  2018-09-21     x  4GB  iOS 12.0       x

# %%
iphone_df.loc[['iPhone 7', 'iPhone X']]
# Out:
#                  출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7  2016-09-16     x  2GB  iOS 10.0       x
# iPhone X  2017-11-03     x  3GB  iOS 11.1       x

# %%
iphone_df.loc[['iPhone 7', 'iPhone X']] = 'o'
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7                o     o    o         o       o
# iPhone 7 Plus  2016-09-16     x  3GB  iOS 10.0       x
# iPhone 8       2016-09-22     x  2GB  iOS 11.0       x
# iPhone 8 Plus  2017-09-22     x  3GB  iOS 11.0       x
# iPhone X                o     o    o         o       o
# iPhone XS      2018-09-21     x  4GB  iOS 12.0       x
# iPhone XS Max  2018-09-21     x  4GB  iOS 12.0       x

# %%
iphone_df.loc['iPhone 7' : 'iPhone X'] = 'o'
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7                o     o    o         o       o
# iPhone 7 Plus           o     o    o         o       o
# iPhone 8                o     o    o         o       o
# iPhone 8 Plus           o     o    o         o       o
# iPhone X                o     o    o         o       o
# iPhone XS      2018-09-21     x  4GB  iOS 12.0       x
# iPhone XS Max  2018-09-21     x  4GB  iOS 12.0       x

# %%
iphone_new_df = pd.read_csv('data/iphone.csv', index_col=0)  # 새로 불러오기
iphone_new_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_new_df['디스플레이'] > 5
# Out:
# iPhone 7         False
# iPhone 7 Plus     True
# iPhone 8         False
# iPhone 8 Plus     True
# iPhone X          True
# iPhone XS         True
# iPhone XS Max     True
# Name: 디스플레이, dtype: bool

# %%
iphone_new_df.loc[iphone_new_df['디스플레이'] > 5]
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_new_df.loc[iphone_new_df['디스플레이'] > 5] = 'p'  # 조건으로 여러 줄 값 바꾸기
iphone_new_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No
# iPhone 7 Plus           p     p    p         p       p
# iPhone 8       2017-09-22   4.7  2GB  iOS 11.0      No
# iPhone 8 Plus           p     p    p         p       p
# iPhone X                p     p    p         p       p
# iPhone XS               p     p    p         p       p
# iPhone XS Max           p     p    p         p       p

# %%
iphone_new_df.iloc[[1,3], [1,4]]
# Out:
#               디스플레이 Face ID
# iPhone 7 Plus     p       p
# iPhone 8 Plus     p       p

# %%
iphone_new_df.iloc[[1,3], [1,4]] = 'v'
iphone_new_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No
# iPhone 7 Plus           p     v    p         p       v
# iPhone 8       2017-09-22   4.7  2GB  iOS 11.0      No
# iPhone 8 Plus           p     v    p         p       v
# iPhone X                p     p    p         p       p
# iPhone XS               p     p    p         p       p
# iPhone XS Max           p     p    p         p       p

# %%
iphone_df = pd.read_csv('data/iphone.csv', index_col = 0)
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df.loc['iPhone XR'] = ['2018-10-26', 6.1, '3GB', 'iOS 12.0.1', 'Yes']  # 새로운 row 추가
iphone_df
# Out:
#                       출시일  디스플레이  메모리       출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB    iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB    iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB    iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB    iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB    iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB    iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB    iOS 12.0     Yes
# iPhone XR      2018-10-26    6.1  3GB  iOS 12.0.1     Yes

# %%
iphone_df['제조사'] = 'Apple'  # 새로운 column 추가
iphone_df
# Out:
#                       출시일  디스플레이  메모리       출시 버전 Face ID    제조사
# iPhone 7       2016-09-16    4.7  2GB    iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16    5.5  3GB    iOS 10.0      No  Apple
# iPhone 8       2017-09-22    4.7  2GB    iOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22    5.5  3GB    iOS 11.0      No  Apple
# iPhone X       2017-11-03    5.8  3GB    iOS 11.1     Yes  Apple
# iPhone XS      2018-09-21    5.8  4GB    iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21    6.5  4GB    iOS 12.0     Yes  Apple
# iPhone XR      2018-10-26    6.1  3GB  iOS 12.0.1     Yes  Apple

# %%
iphone_df.drop('iPhone XR', axis='index', inplace=False)  # row 삭제(index는 row), inplace=False로 설정 시 기존 데이터 변경 없음
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID    제조사
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No  Apple
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No  Apple
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes  Apple
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes  Apple

# %%
iphone_df  # 다시 출력해보면 iPhone XR이 삭제되지 않았다.
# Out:
#                       출시일  디스플레이  메모리       출시 버전 Face ID    제조사
# iPhone 7       2016-09-16    4.7  2GB    iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16    5.5  3GB    iOS 10.0      No  Apple
# iPhone 8       2017-09-22    4.7  2GB    iOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22    5.5  3GB    iOS 11.0      No  Apple
# iPhone X       2017-11-03    5.8  3GB    iOS 11.1     Yes  Apple
# iPhone XS      2018-09-21    5.8  4GB    iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21    6.5  4GB    iOS 12.0     Yes  Apple
# iPhone XR      2018-10-26    6.1  3GB  iOS 12.0.1     Yes  Apple

# %%
iphone_df.drop('iPhone XR', axis='index', inplace=True)  # iphone_df 자체의 데이터를 변경

# %%
iphone_df  # 삭제된 거 확인
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID    제조사
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No  Apple
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No  Apple
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes  Apple
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes  Apple

# %%
iphone_df.drop('제조사', axis='columns', inplace=True)  # column 삭제
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df.drop(['iPhone 7', 'iPhone 8', 'iPhone X'], axis='index', inplace=True)  # 여러 줄 삭제

# %%
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %% [markdown]
# ### 잘못된 DataFrame 수정하기
#
# 1. ID 1의 무게를 200으로 변경하세요.
# 2. ID 21의 row를 삭제하세요.
# 3. ID 20의 row를 추가하세요. ID 20의 키는 70, 무게는 200입니다.

# %%
import pandas as pd

df = pd.read_csv('data/body_imperial1.csv', index_col=0)

df.loc[1, 'Weight (Pound)'] = 200
df.drop(21, axis='index', inplace=True)
df.loc[20] = [70, 200]

df
# Out:
#     Height (Inch)  Weight (Pound)
# ID
# 0       73.847017      241.893563
# 1       70.000000      200.000000
# 2       74.110105      212.740856
# 3       71.730978      220.042470
# 4       69.881796      206.349801
# 5       67.253016      152.212156
# 6       68.785081      183.927889
# 7       68.348516      167.971110
# 8       67.018950      175.929440
# 9       63.456494      156.399676
# 10      71.195382      186.604926
# 11      62.636675      102.853563
# 12      62.077832      138.691680
# 13      60.030434       97.687432
# 14      59.098250      110.529686
# 15      66.172652      136.777454
# 16      67.067155      170.867906
# 17      63.867992      128.475319
# 18      69.034243      163.852461
# 19      61.944246      113.649103
# 20      70.000000      200.000000

# %% [markdown]
# ### 잘못된 데이터 수정하기 2
#
# 1. '비만도' column을 추가하고, 모든 ID에 대해 '정상'으로 설정해주세요.
# 2. 'Gender' column의 값을 ID 0\~10까지는 'Male' 11~20까지는 'Female'로 변경하세요.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/body_imperial2.csv', index_col=0)

df['비만도'] = '정상'
df.loc[:10, 'Gender'] = 'Male'
df.loc[11:, 'Gender'] = 'Female'

df
# Out:
#     Gender  Height (Inch)  Weight (Pound) 비만도
# ID
# 0     Male      73.847017      241.893563  정상
# 1     Male      70.000000      200.000000  정상
# 2     Male      74.110105      212.740856  정상
# 3     Male      71.730978      220.042470  정상
# 4     Male      69.881796      206.349801  정상
# 5     Male      67.253016      152.212156  정상
# 6     Male      68.785081      183.927889  정상
# 7     Male      68.348516      167.971110  정상
# 8     Male      67.018950      175.929440  정상
# 9     Male      63.456494      156.399676  정상
# 10    Male      71.195382      186.604926  정상
# 11  Female      62.636675      102.853563  정상
# 12  Female      62.077832      138.691680  정상
# 13  Female      60.030434       97.687432  정상
# 14  Female      59.098250      110.529686  정상
# 15  Female      66.172652      136.777454  정상
# 16  Female      67.067155      170.867906  정상
# 17  Female      63.867992      128.475319  정상
# 18  Female      69.034243      163.852461  정상
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/body_imperial2.csv', index_col=0)
df['비만도'] = '정상'
df['Gender'] = np.where(df.index <= 10, "Male", "Female")  # 한 줄로 표현도 가능하다. 

df
# Out:
#     Gender  Height (Inch)  Weight (Pound) 비만도
# ID
# 0     Male      73.847017      241.893563  정상
# 1     Male      70.000000      200.000000  정상
# 2     Male      74.110105      212.740856  정상
# 3     Male      71.730978      220.042470  정상
# 4     Male      69.881796      206.349801  정상
# 5     Male      67.253016      152.212156  정상
# 6     Male      68.785081      183.927889  정상
# 7     Male      68.348516      167.971110  정상
# 8     Male      67.018950      175.929440  정상
# 9     Male      63.456494      156.399676  정상
# 10    Male      71.195382      186.604926  정상
# 11  Female      62.636675      102.853563  정상
# 12  Female      62.077832      138.691680  정상
# 13  Female      60.030434       97.687432  정상
# 14  Female      59.098250      110.529686  정상
# 15  Female      66.172652      136.777454  정상
# 16  Female      67.067155      170.867906  정상
# 17  Female      63.867992      128.475319  정상
# 18  Female      69.034243      163.852461  정상
# ...

# %% [markdown]
# <br><br>

# %%
liverpool_df = pd.read_csv('data/liverpool.csv', index_col=0)
liverpool_df
# Out:
#                 position  born  number nationality
# Roberto Firmino       FW  1991   no. 9      Brazil
# Sadio Mane            FW  1992  no. 10     Senegal
# Mohamed Salah         FW  1992  no. 11       Egypt
# Joe Gomez             DF  1997  no. 12     England
# Alisson Becker        GK  1992  no. 13      Brazil

# %%
liverpool_df.rename(columns={'position' : 'Position'})  # column명 변경(기존 컬럼명 : 변경 컬럼명)
# Out:
#                 Position  born  number nationality
# Roberto Firmino       FW  1991   no. 9      Brazil
# Sadio Mane            FW  1992  no. 10     Senegal
# Mohamed Salah         FW  1992  no. 11       Egypt
# Joe Gomez             DF  1997  no. 12     England
# Alisson Becker        GK  1992  no. 13      Brazil

# %%
liverpool_df
# Out:
#                 position  born  number nationality
# Roberto Firmino       FW  1991   no. 9      Brazil
# Sadio Mane            FW  1992  no. 10     Senegal
# Mohamed Salah         FW  1992  no. 11       Egypt
# Joe Gomez             DF  1997  no. 12     England
# Alisson Becker        GK  1992  no. 13      Brazil

# %% [markdown]
# 컬럼명 변경하기 위해 rename 메소드를 사용했는데, 다시 출력해보면 변경이 적용되지 않았음을 확인할 수 있다. rename으로 컬럼명을 변경 시 DataFrame의 데이터를 직접 변경하는 것이 아닌 변경된 새로운 DataFrame을 만든다. 따라서 새로운 변수에 저장하거나 옵션을 줘야 한다.

# %%
liverpool_df.rename(columns={'position' : 'Position'}, inplace=True)

# %%
liverpool_df
# Out:
#                 Position  born  number nationality
# Roberto Firmino       FW  1991   no. 9      Brazil
# Sadio Mane            FW  1992  no. 10     Senegal
# Mohamed Salah         FW  1992  no. 11       Egypt
# Joe Gomez             DF  1997  no. 12     England
# Alisson Becker        GK  1992  no. 13      Brazil

# %%
liverpool_df.rename(columns={'position':'Position', 'born':'Born', 'number':'Number', 'nationality':'Nationality'}, inplace=True)

# %%
liverpool_df
# Out:
#                 Position  Born  Number Nationality
# Roberto Firmino       FW  1991   no. 9      Brazil
# Sadio Mane            FW  1992  no. 10     Senegal
# Mohamed Salah         FW  1992  no. 11       Egypt
# Joe Gomez             DF  1997  no. 12     England
# Alisson Becker        GK  1992  no. 13      Brazil

# %%
liverpool_df.index.name = 'Player Name'  # index 이름

# %%
liverpool_df
# Out:
#                 Position  Born  Number Nationality
# Player Name
# Roberto Firmino       FW  1991   no. 9      Brazil
# Sadio Mane            FW  1992  no. 10     Senegal
# Mohamed Salah         FW  1992  no. 11       Egypt
# Joe Gomez             DF  1997  no. 12     England
# Alisson Becker        GK  1992  no. 13      Brazil

# %%
liverpool_df.set_index('Number')  # index 자체를 변경하기(기존 index는 삭제되기 때문에 백업해둬야 함)
# Out:
#        Position  Born Nationality
# Number
# no. 9        FW  1991      Brazil
# no. 10       FW  1992     Senegal
# no. 11       FW  1992       Egypt
# no. 12       DF  1997     England
# no. 13       GK  1992      Brazil

# %%
liverpool_df.index
# Out:
# Index(['Roberto Firmino', 'Sadio Mane', 'Mohamed Salah', 'Joe Gomez',
#        'Alisson Becker'],
#       dtype='object', name='Player Name')

# %%
liverpool_df['Player Name'] = liverpool_df.index  # 백업

# %%
liverpool_df
# Out:
#                 Position  Born  Number Nationality      Player Name
# Player Name
# Roberto Firmino       FW  1991   no. 9      Brazil  Roberto Firmino
# Sadio Mane            FW  1992  no. 10     Senegal       Sadio Mane
# Mohamed Salah         FW  1992  no. 11       Egypt    Mohamed Salah
# Joe Gomez             DF  1997  no. 12     England        Joe Gomez
# Alisson Becker        GK  1992  no. 13      Brazil   Alisson Becker

# %%
liverpool_df.set_index('Number', inplace=True)  # index는 중복 값이 없는 컬럼으로 설정해야함.
liverpool_df
# Out:
#        Position  Born Nationality      Player Name
# Number
# no. 9        FW  1991      Brazil  Roberto Firmino
# no. 10       FW  1992     Senegal       Sadio Mane
# no. 11       FW  1992       Egypt    Mohamed Salah
# no. 12       DF  1997     England        Joe Gomez
# no. 13       GK  1992      Brazil   Alisson Becker

# %% [markdown]
# <br><br>
# ### 데이터프레임 조건에 맞게 바꾸기
#
# 1. 'A' column이 모두 2배가 되었습니다.
# 2. 'B'에서 'E'까지의 column은 80보다 큰 것은 1, 작은 것은 0으로 바뀌었습니다.
# 3. 2번 index의 'F' column 값이 29에서 99로 바뀌었습니다.

# %%
import pandas as pd

df = pd.read_csv('https://github.com/codeit-courses/data-science/raw/master/Puzzle_before.csv')
df
# Out:
#    A   B   C   D   E   F
# 0  1  55  70  87  56  13
# 1  2  45  60  99  53  24
# 2  3  88  70  94  39  29
# 3  4  97  80  24  83  78
# 4  5  13  90  26  80  61

# %%
df['A'] *= 2
df[df.loc[:, 'B':'E'] < 80] = 0
df[df.loc[:, 'B':'E'] >= 80] = 1
df.loc[2, 'F'] = 99

df
# Out:
#     A  B  C  D  E   F
# 0   2  0  0  1  0  13
# 1   4  0  0  1  0  24
# 2   6  1  0  1  0  99
# 3   8  1  1  0  1  78
# 4  10  0  1  0  1  61

# %% [markdown]
# <br><br>
# # 큰 데이터 다루기

# %%
import pandas as pd

# %%
laptops_df = pd.read_csv('data/laptops.csv')

# %%
laptops_df
# Out:
#      brand             model  ram hd_type  hd_size  screen_size   price  \
# 0     Dell  Inspiron 15-3567    4     hdd     1024         15.6   40000
# 1    Apple       MacBook Air    8     ssd      128         13.3   55499
# 2    Apple       MacBook Air    8     ssd      256         13.3   71500
# 3    Apple       MacBook Pro    8     ssd      128         13.3   96890
# 4    Apple       MacBook Pro    8     ssd      256         13.3  112666
# ..     ...               ...  ...     ...      ...          ...     ...
# 162   Asus            A555LF    8     hdd     1024         15.6   39961
# 163   Asus     X555LA-XX172D    4     hdd      500         15.6   28489
# 164   Asus            X554LD    2     hdd      500         15.6   29199
# 165   Asus    X550LAV-XX771D    2     hdd      500         15.6   29990
# 166   Asus     X540LA-XX538T    4     hdd     1024         15.6   30899
#
#     processor_brand processor_model  clock_speed graphic_card_brand  \
# ...

# %%
laptops_df.head(3)  # 데이터가 많을 경우 위에 3줄 출력하기
# Out:
#    brand             model  ram hd_type  hd_size  screen_size  price  \
# 0   Dell  Inspiron 15-3567    4     hdd     1024         15.6  40000
# 1  Apple       MacBook Air    8     ssd      128         13.3  55499
# 2  Apple       MacBook Air    8     ssd      256         13.3  71500
#
#   processor_brand processor_model  clock_speed graphic_card_brand  \
# 0           intel              i5          2.5              intel
# 1           intel              i5          1.8              intel
# 2           intel              i5          1.8              intel
#
#    graphic_card_size     os  weight comments
# 0                NaN  linux    2.50      NaN
# 1                2.0    mac    1.35      NaN
# 2                2.0    mac    1.35      NaN

# %%
laptops_df.tail(5)  # 마지막 5줄 출력하기
# Out:
#     brand           model  ram hd_type  hd_size  screen_size  price  \
# 162  Asus          A555LF    8     hdd     1024         15.6  39961
# 163  Asus   X555LA-XX172D    4     hdd      500         15.6  28489
# 164  Asus          X554LD    2     hdd      500         15.6  29199
# 165  Asus  X550LAV-XX771D    2     hdd      500         15.6  29990
# 166  Asus   X540LA-XX538T    4     hdd     1024         15.6  30899
#
#     processor_brand processor_model  clock_speed graphic_card_brand  \
# 162           intel      i3 4th gen          1.7             nvidia
# 163           intel      i3 4th gen          1.9              intel
# 164           intel      i3 4th gen          1.9              intel
# 165           intel      i3 4th gen          1.7              intel
# 166           intel      i3 5th gen          2.0              intel
#
#      graphic_card_size       os  weight comments
# 162                2.0  windows     2.3      NaN
# ...

# %%
laptops_df.shape  # DataFrame 형태
# Out:
# (167, 15)

# %%
laptops_df.columns  # column 종류
# Out:
# Index(['brand', 'model', 'ram', 'hd_type', 'hd_size', 'screen_size', 'price',
#        'processor_brand', 'processor_model', 'clock_speed',
#        'graphic_card_brand', 'graphic_card_size', 'os', 'weight', 'comments'],
#       dtype='object')

# %%
laptops_df.info()  # column의 기본 정보
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   brand               167 non-null    object
#  1   model               167 non-null    object
#  2   ram                 167 non-null    int64
#  3   hd_type             167 non-null    object
#  4   hd_size             167 non-null    int64
#  5   screen_size         167 non-null    float64
#  6   price               167 non-null    int64
#  7   processor_brand     167 non-null    object
#  8   processor_model     167 non-null    object
#  9   clock_speed         166 non-null    float64
#  10  graphic_card_brand  163 non-null    object
#  11  graphic_card_size   81 non-null     float64
#  12  os                  167 non-null    object
#  13  weight              160 non-null    float64
#  14  comments            55 non-null     object
# ...

# %%
laptops_df.describe()  # 통계
# Out:
#               ram     hd_size  screen_size          price  clock_speed  \
# count  167.000000   167.00000   167.000000     167.000000   166.000000
# mean     6.898204   768.91018    14.775210   64132.898204     2.321084
# std      3.787479   392.99080     1.376526   42797.674010     0.554187
# min      2.000000    32.00000    10.100000   13872.000000     1.100000
# 25%      4.000000   500.00000    14.000000   35457.500000     1.900000
# 50%      8.000000  1024.00000    15.600000   47990.000000     2.300000
# 75%      8.000000  1024.00000    15.600000   77494.500000     2.600000
# max     16.000000  2048.00000    17.600000  226000.000000     3.800000
#
#        graphic_card_size      weight
# count          81.000000  160.000000
# mean           52.160494    2.250812
# std           444.134142    0.648446
# min             1.000000    0.780000
# 25%             2.000000    1.900000
# 50%             2.000000    2.200000
# 75%             4.000000    2.600000
# ...

# %%
laptops_df.sort_values(by='price')  # price column 기준으로 정렬(오름차순)
# Out:
#          brand                       model  ram hd_type  hd_size  screen_size  \
# 148       Acer             Aspire SW3-016     2     ssd       32         10.1
# 83        Acer     A315-31CDC UN.GNTSI.001    2     ssd      500         15.6
# 108       Acer  Aspire ES-15 NX.GKYSI.010     4     hdd      500         15.6
# 100       Acer    A315-31-P4CRUN.GNTSI.002    4     hdd      500         15.6
# 73        Acer             Aspire ES1-523     4     hdd     1024         15.6
# ..         ...                         ...  ...     ...      ...          ...
# 154  Microsoft      Surface Book CR9-00013    8     ssd      128         13.5
# 31        Acer                 Predator 17   16     ssd      256         17.3
# 96   Alienware          AW13R3-7000SLV-PUS    8     ssd      256         13.3
# 90   Alienware                 15 Notebook   16     hdd     1024         15.6
# 5        Apple      MacBook Pro (TouchBar)   16     ssd      512         15.0
#
# ...

# %%
laptops_df.sort_values(by='price', ascending=False)  # 내림차순
# Out:
#          brand                       model  ram hd_type  hd_size  screen_size  \
# 5        Apple      MacBook Pro (TouchBar)   16     ssd      512         15.0
# 90   Alienware                 15 Notebook   16     hdd     1024         15.6
# 96   Alienware          AW13R3-7000SLV-PUS    8     ssd      256         13.3
# 31        Acer                 Predator 17   16     ssd      256         17.3
# 154  Microsoft      Surface Book CR9-00013    8     ssd      128         13.5
# ..         ...                         ...  ...     ...      ...          ...
# 73        Acer             Aspire ES1-523     4     hdd     1024         15.6
# 100       Acer    A315-31-P4CRUN.GNTSI.002    4     hdd      500         15.6
# 108       Acer  Aspire ES-15 NX.GKYSI.010     4     hdd      500         15.6
# 83        Acer     A315-31CDC UN.GNTSI.001    2     ssd      500         15.6
# 148       Acer             Aspire SW3-016     2     ssd       32         10.1
#
# ...

# %%
laptops_df  # sort_values 적용 안 됨
# Out:
#      brand             model  ram hd_type  hd_size  screen_size   price  \
# 0     Dell  Inspiron 15-3567    4     hdd     1024         15.6   40000
# 1    Apple       MacBook Air    8     ssd      128         13.3   55499
# 2    Apple       MacBook Air    8     ssd      256         13.3   71500
# 3    Apple       MacBook Pro    8     ssd      128         13.3   96890
# 4    Apple       MacBook Pro    8     ssd      256         13.3  112666
# ..     ...               ...  ...     ...      ...          ...     ...
# 162   Asus            A555LF    8     hdd     1024         15.6   39961
# 163   Asus     X555LA-XX172D    4     hdd      500         15.6   28489
# 164   Asus            X554LD    2     hdd      500         15.6   29199
# 165   Asus    X550LAV-XX771D    2     hdd      500         15.6   29990
# 166   Asus     X540LA-XX538T    4     hdd     1024         15.6   30899
#
#     processor_brand processor_model  clock_speed graphic_card_brand  \
# ...

# %%
laptops_df.sort_values(by='price', ascending=False, inplace=True)  # DataFrame에 적용

# %%
laptops_df  # price column 기준으로 정렬한 내용 적용
# Out:
#          brand                       model  ram hd_type  hd_size  screen_size  \
# 5        Apple      MacBook Pro (TouchBar)   16     ssd      512         15.0
# 90   Alienware                 15 Notebook   16     hdd     1024         15.6
# 96   Alienware          AW13R3-7000SLV-PUS    8     ssd      256         13.3
# 31        Acer                 Predator 17   16     ssd      256         17.3
# 154  Microsoft      Surface Book CR9-00013    8     ssd      128         13.5
# ..         ...                         ...  ...     ...      ...          ...
# 73        Acer             Aspire ES1-523     4     hdd     1024         15.6
# 100       Acer    A315-31-P4CRUN.GNTSI.002    4     hdd      500         15.6
# 108       Acer  Aspire ES-15 NX.GKYSI.010     4     hdd      500         15.6
# 83        Acer     A315-31CDC UN.GNTSI.001    2     ssd      500         15.6
# 148       Acer             Aspire SW3-016     2     ssd       32         10.1
#
# ...

# %%
laptops_df['brand']
# Out:
# 5          Apple
# 90     Alienware
# 96     Alienware
# 31          Acer
# 154    Microsoft
#          ...
# 73          Acer
# 100         Acer
# 108         Acer
# 83          Acer
# 148         Acer
# Name: brand, Length: 167, dtype: object

# %%
laptops_df['brand'].unique()  # 중복값 제거
# Out:
# array(['Apple', 'Alienware', 'Acer', 'Microsoft', 'HP', 'Dell', 'Lenovo',
#        'Asus'], dtype=object)

# %%
laptops_df['brand'].value_counts()  # column 값별로 몇 개씩 나오는지 확인
# Out:
# HP           55
# Acer         35
# Dell         31
# Lenovo       18
# Asus          9
# Apple         7
# Alienware     6
# Microsoft     6
# Name: brand, dtype: int64

# %%
laptops_df['brand'].describe()
# Out:
# count     167
# unique      8
# top        HP
# freq       55
# Name: brand, dtype: object

# %% [markdown]
# count : 총 요소의 개수
# unique : 중복 제거한 값의 개수
# top : 제일 많은 항목
# freq : top의 개수
